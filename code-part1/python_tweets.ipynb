# %%
import csv
file = open("crime_100000_cleaned.txt","w") 
with open('crime_100000_cleaned.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        file.write(row[1]) 
        line_count=line_count+1
    print(f'Processed {line_count} lines.')
    
file.close()
# Out:
# Processed 46788 lines.

# %%
import tweepy

# %%
consumer_key        = "xxx"
consumer_secret     = "xxxx"
access_token        = "xxx-xx"
access_token_secret = "xxxxxx"

# %%
# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)

# %%
# Creating the API object while passing in auth information
api = tweepy.API(auth)

# The search term you want to find
query = "theft"
# Language code (follows ISO 639-1 standards)
language = "en"

# Calling the user_timeline function with our parameters
results = api.search(q=query, lang=language,  count=20)

# foreach through all tweets pulled
for tweet in results:
   # printing the text stored inside the tweet object
    print (tweet.user.screen_name,"Tweeted:",tweet.text)
    print("\n\n")
# Out:
# TamsinFlower1 Tweeted: #Rhiannon the Horse Goddess was scapegoated by nurse-maids who witnessed her baby's theft. Accused of killing her o… https://t.co/YgKuzqGSMV
#
#
#
# JoshGIII Tweeted: RT @TalbertSwan: Remember Tanya McDowell?
# She’s a Black woman sentenced to 5 yrs for “larceny of an education” for sending her son to a sch…
#
#
#
# TomFerr51436763 Tweeted: @JimmyPatronis @CrimDivision @PBSOHSB @MDEA_Maine @JPerezMDPD most jax 2 miami 9-4 drivers are drivng Stolen vehicl… https://t.co/yCo2JTM6X5
#
#
#
# uncannyjean Tweeted: @mercari_app [paraphrasing] "Sorry you spent $150 on fake items, but here's $150 in mercari credit." Are you kiddin… https://t.co/s6lB07E7zt
#
#
#
# shekharnaughty Tweeted: RT @AJEnglish: Unemployment and poverty are forcing many young Nigerians to turn to oil 'theft' - which they say is rightfully theirs. http…
#
#
#
# ...

# %%
##Read the file
#file = open("part-00000","r") 
#print( file.read()) 

articles = api.search(q = query,begin_date = '20100101',end_date = '20101231', sort='oldest', page = str(1))

# %%
from nytimesarticle import articleAPI
api = articleAPI('GQ0savljLHI6xpu3Ubucn85bx9duMW0T')

# %%
articles = api.search( q = 'crime',begin_date = 20111231 )

articles = api.search(q = 'crime',begin_date = 20100101,end_date = 20101231, page = 0, facet_filter=True)

count = 0
for i in articles['response']['docs']:
    pprint(i)
    break
    count+=1
print(count)
# Out:
# {'_id': '5421646c38f0d81f7a60169b',
#  'blog': {},
#  'byline': {'organization': None,
#             'original': 'By MARILYN STASIO',
#             'person': [{'firstname': 'Marilyn',
#                         'lastname': 'STASIO',
#                         'middlename': None,
#                         'organization': '',
#                         'qualifier': None,
#                         'rank': 1,
#                         'role': 'reported',
#                         'title': None}]},
#  'document_type': 'article',
#  'headline': {'content_kicker': 'Crime',
#               'kicker': 'Crime',
#               'main': 'Baker Street Irregular',
#               'name': None,
#               'print_headline': 'Baker Street Irregular',
#               'seo': 'Crime Novels by Graham Moore, Sheldon Russell, Grant '
#                      'Jerkins and Debra Ginsberg',
#               'sub': None},
#  'keywords': [{'major': None,
#                'name': 'subject',
# ...

# %%
url = "https://www.nytimes.com/2010/12/26/books/review/Crime-t.html";

resp = requests.get(url)
# data = json.loads(resp.text)
print(resp.text)
# Out:
# <!DOCTYPE html>
# <!--[if (gt IE 9)|!(IE)]> <!--> <html lang="en" class="no-js section-review format-medium tone-feature app-article page-theme-standard  has-top-ad type-size-small" itemprop="review"itemid="https://www.nytimes.com/2010/12/26/books/review/Crime-t.html" itemtype="http://schema.org/Review"  itemscope xmlns:og="http://opengraphprotocol.org/schema/"> <!--<![endif]-->
# <!--[if IE 9]> <html lang="en" class="no-js ie9 lt-ie10 section-review format-medium tone-feature app-article page-theme-standard  has-top-ad type-size-small" xmlns:og="http://opengraphprotocol.org/schema/"> <![endif]-->
# <!--[if IE 8]> <html lang="en" class="no-js ie8 lt-ie10 lt-ie9 section-review format-medium tone-feature app-article page-theme-standard  has-top-ad type-size-small" xmlns:og="http://opengraphprotocol.org/schema/"> <![endif]-->
# ...

# %%
articles = api.search( q = 'crime',begin_date = 20111231 )

# %%
def parse_articles(articles):
    '''
    This function takes in a response to the NYT api and parses
    the articles into a list of dictionaries
    '''
    news = []
    for i in articles['response']['docs']:
        print(i)
        '''dic = {}
        dic['id'] = i['_id']
        if i['lead_paragraph'] is not None:
            dic['abstract'] = i['abstract'].encode("utf8")
        dic['headline'] = i['headline']['main'].encode("utf8")
        dic['desk'] = i['news_desk']
        dic['date'] = i['pub_date'][0:10] # cutting time of day.
        dic['section'] = i['section_name']
        if i['snippet'] is not None:
            dic['snippet'] = i['snippet'].encode("utf8")
        dic['source'] = i['source']
        dic['type'] = i['type_of_material']
        dic['url'] = i['web_url']
        dic['word_count'] = i['word_count']
        # locations
        locations = []
        for x in range(0,len(i['keywords'])):
            if 'glocations' in i['keywords'][x]['name']:
                locations.append(i['keywords'][x]['value'])
        dic['locations'] = locations
        # subject
        subjects = []
        for x in range(0,len(i['keywords'])):
            if 'subject' in i['keywords'][x]['name']:
                subjects.append(i['keywords'][x]['value'])
        dic['subjects'] = subjects   
        news.append(dic)'''
        dic = {}
        dic['id'] = i['_id']
        if i['snippet'] is not None:
            dic['snippet'] = i['snippet'].encode("utf8")
    return(news)

# %%
def get_articles(date,query):
    '''
    This function accepts a year in string format (e.g.'1980')
    and a query (e.g.'Amnesty International') and it will 
    return a list of parsed articles (in dictionaries)
    for that year.
    '''
    all_articles = []
    for i in range(0,100): #NYT limits pager to first 100 pages. But rarely will you find over 100 pages of results anyway.
        articles = api.search(q = query, begin_date = int(date + '0101'), end_date = int(date + '1231'), page = i)
        articles = parse_articles(articles)
        all_articles = all_articles + articles
    return(all_articles)

# %%
Amnesty_all = []
for i in range(1980,2014):
    print("Processing " , str(i))
    Amnesty_year = get_articles(str(i),'Amnesty International')
    Amnesty_all = Amnesty_all + Amnesty_year
# Out:
# Processing  1980
# ...

# %%
print("Q")
# Out:
# Q

# %%
int('8989')
# Out:
# 8989

# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.nytimes.com/2019/04/18/lens/a-photographer-confronts-his-familys-tragic-past-in-colombias-war.html')
doc = BeautifulSoup(response.text, 'html.parser')

# %%
story = doc.find_all('article', { 'class': 'story' })

for story in story[:11]:
    print("This is a story")
    print(story.text)

# %%
links = doc.find_all('a')

for link in links[:10]:
    print("\n\n\nThis is a link")
    print(link.text)
# Out:
# This is a link
# Skip to content
#
#
#
# This is a link
# Skip to site index
#
#
#
# This is a link
#
#
#
#
# This is a link
# Subscribe
#
#
#
# This is a link
# Log In
#
#
#
# This is a link
# Log In
#
#
#
# This is a link
# Today’s Paper
#
#
#
# This is a link
# Lens
#
#
#
# This is a link
#
#
#
#
# This is a link

# %%
import requests  
r = requests.get('https://www.nytimes.com/2010/12/26/books/review/Crime-t.html')

from bs4 import BeautifulSoup  
soup = BeautifulSoup(r.text, 'html.parser')  
results = soup.find_all('span', attrs={'class':'short-desc'})

records = []  
for result in results:  
    date = result.find('strong').text[0:-1] + ', 2017'
    lie = result.contents[1][1:-2]
    explanation = result.find('a').text[1:-1]
    url = result.find('a')['href']
    records.append((date, lie, explanation, url))

import pandas as pd  
df = pd.DataFrame(records, columns=['date', 'lie', 'explanation', 'url'])  
df['date'] = pd.to_datetime(df['date'])  
df.to_csv('crime_nyt.csv', index=False, encoding='utf-8')

# %%
query_text = "toy"
r = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q="+query_text+"&begin_date=20161001&api-key=GQ0savljLHI6xpu3Ubucn85bx9duMW0T")
data = r.json()
print(len(data["response"]["docs"]))
# print(data)
for urls in data["response"]["docs"] :
    print(urls["web_url"])
# Out:
# 10
# https://www.nytimes.com/aponline/2019/04/11/us/ap-us-toys-r-us-lingering-impact.html
# https://www.nytimes.com/slideshow/2019/02/28/t-magazine/of-a-kind-paul-smith-toys.html
# https://www.nytimes.com/paidpost/china-daily/snaring-toys-by-machine-requires-a-combination-of-skill-and-luck.html
# https://www.nytimes.com/2019/03/29/movies/scary-stories-to-tell-in-the-dark-trailer.html
# https://www.nytimes.com/2019/04/03/t-magazine/charles-renfro-kenner-building-set.html
# https://www.nytimes.com/2018/11/12/movies/toy-story-4-trailer.html
# https://www.nytimes.com/aponline/2019/04/12/health/ap-us-med-kids-swallowed-objects.html
# https://www.nytimes.com/2019/02/15/business/toys-r-us-return.html
# https://www.nytimes.com/2019/01/28/opinion/crispr-genes-babies.html
# https://www.nytimes.com/video/embedded/movies/100000006210699/trailer-toy-story-4.html

# %%
import json, requests
from pprint import pprint
url = "http://api.nytimes.com/svc/search/v2/articlesearch.json?q=crime&page=2&sort=oldest&api-key=GQ0savljLHI6xpu3Ubucn85bx9duMW0T";

resp = requests.get(url)
data = json.loads(resp.text)

# %%
pprint(data)
# Out:
# {'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights '
#               'Reserved.',
#  'response': {'docs': [{'_id': '4fbfd9c045c1498b0d0284ff',
#                         'blog': {},
#                         'document_type': 'article',
#                         'headline': {'content_kicker': None,
#                                      'kicker': '1',
#                                      'main': 'Education and Crime.',
#                                      'name': None,
#                                      'print_headline': None,
#                                      'seo': None,
#                                      'sub': None},
#                         'keywords': [],
#                         'lead_paragraph': 'Over a fortnight since Mr. '
#                                           'McMASTER, the Editor of the '
#                                           "Freeman's Journal, and a gentleman "
# ...

# %%
for key in data:
    print (key)
# Out:
# status
# copyright
# response

# %%
pprint(data["response"])
# Out:
# {'docs': [{'_id': '4fbfd9c045c1498b0d0284ff',
#            'blog': {},
#            'document_type': 'article',
#            'headline': {'content_kicker': None,
#                         'kicker': '1',
#                         'main': 'Education and Crime.',
#                         'name': None,
#                         'print_headline': None,
#                         'seo': None,
#                         'sub': None},
#            'keywords': [],
#            'lead_paragraph': 'Over a fortnight since Mr. McMASTER, the Editor '
#                              "of the Freeman's Journal, and a gentleman of "
#                              'character and public position, in a lecture '
#                              'delivered at Metropolitan Hall, stated as a '
#                              'matter of fact, that "prominent on the list "of '
#                              'those persons arrested and convicted of "crime '
# ...

# %%
pprint(data["response"]["docs"][0])
# Out:
# {'_id': '4fbfd9c045c1498b0d0284ff',
#  'blog': {},
#  'document_type': 'article',
#  'headline': {'content_kicker': None,
#               'kicker': '1',
#               'main': 'Education and Crime.',
#               'name': None,
#               'print_headline': None,
#               'seo': None,
#               'sub': None},
#  'keywords': [],
#  'lead_paragraph': 'Over a fortnight since Mr. McMASTER, the Editor of the '
#                    "Freeman's Journal, and a gentleman of character and public "
#                    'position, in a lecture delivered at Metropolitan Hall, '
#                    'stated as a matter of fact, that "prominent on the list '
#                    '"of those persons arrested and convicted of "crime in this '
#                    'City, would be found the names "of those who had stood '
#                    'foremost in our Public "Schools."',
#  'multimedia': [],
#  'print_page': '4',
#  'pub_date': '1853-01-22T00:03:58Z',
#  'score': 0.0,
# ...

# %%
for key in data["response"]["docs"]:
    print("\n\n" + key["headline"]["main"] )
# Out:
# Education and Crime.
#
#
# Crimes and Accidents.
#
#
# Arthur Spring--His Admissions and Retractions--Another Intended Crime Acknowledged.
#
#
# Crimes Due to Drunkenness.
#
#
# EIGHT DAYS LATER FROM CALIFORNIA; ARRIVAL OF THE CRESCENT CITY. $520,300 IN SPECIE. LATER FROM THE ISTHMUS. MINING INTELLIGENCE. THE ISTHMUS. CALIFORNIA. The Largest Tree in the World. Statistics of Crime. Mining Intelilgence. From the Interior. FROM OREGON. Married. Births. Deaths.
#
#
# EIGHT DAYS LATER FROM CALIFORNIA'; ARRIVAL OF THE NORTHERN LIGHT. Later from Sandwich and Society Islands. $2,283,050 ON THE WAY. Passengers. CALIFORNIA. Shipment of Treasure. San Francisco Items. From Other Parts of the State. Mining Accounts. Commerce, Population and Crime of San Francisco. SANDWICH ISLANDS. THE SOCIETY ISLANDS. FROM CHINA. Review of the Market. Financial. THE RECORDER'S OPINION. In the Case of James B. Tayler.
#
#
# A Tale of Awful Crime-Flendish Cruelty.
#
#
# ...

# %%
for key in data["response"]["docs"]:
    print("\n\n" + key["lead_paragraph"] )
# Out:
# Over a fortnight since Mr. McMASTER, the Editor of the Freeman's Journal, and a gentleman of character and public position, in a lecture delivered at Metropolitan Hall, stated as a matter of fact, that "prominent on the list "of those persons arrested and convicted of "crime in this City, would be found the names "of those who had stood foremost in our Public "Schools."
#
#
# The well-known Indian chief, PACHATTA, was killed near Jackson a short time since, by some Chinamen. No particulars heard. An atrocious murder was committed at Sonora by a couple of Mexicans.
#
#
# Since our last issue, ARTHUR SPRING has been induced to make a statement declaring his belief in the innocence of his son of the Federal-street murder. The declaration is as follows: MOYAMENSING PRISON, June 7, 1853.
#
#
# ...
